-2035 CDCBM COBAAR","TK-2035 CDCBM BLACDT","TK-2035 CDCBM PATCOM","TK-2035 CDCBM PATCOM","TK-2035 CDCBM PATCOM","TK-2035 CDCBM PENRBV","TK-2035 CDCBM PENRBV","TK-2035 CDCBM PENRBV","TK-2035 CDCBM RETRTX","TK-2035 CDCBM RETRTX","TK-2035 CDCBM RETRTX","TK-6161 PIMA7 BLUSDQ","TK-6161 PIMA7 BLUSDQ","TK-6161 PIMA7 BLUSDQ","TK-6161 PIMA7 COBAAR","TK-6161 PIMA7 COBAAR","TK-6161 PIMA7 COBAAR","TK-6161 PIMA7 BLACDT","TK-6161 PIMA7 BLACDT","TK-6161 PIMA7 BLACDT","TK-6161 PIMA7 PATCOM","TK-6161 PIMA7 PATCOM","TK-6161 PIMA7 PATCOM","TK-6121 PIMA7 BLUSDQ","TK-6121 PIMA7 BLUSDQ","TK-6121 PIMA7 BLUSDQ","TK-6121 PIMA7 COBAAR","TK-6121 PIMA7 COBAAR","TK-6121 PIMA7 COBAAR","TK-6121 PIMA7 BLACDT","TK-6121 PIMA7 BLACDT","TK-6121 PIMA7 BLACDT","TK-3010 CDCBM BLUSDQ","TK-3010 CDCBM BLUSDQ","TK-3010 CDCBM BLUSDQ","TK-3010 CDCBM COBAAR","TK-3010 CDCBM COBAAR","TK-3010 CDCBM COBAAR","TK-3010 CDCBM BLACDT","TK-3010 CDCBM BLACDT","TK-3010 CDCBM BLACDT","TK-3001 CDCBM COBAAR","TK-3001 CDCBM COBAAR","TK-3001 CDCBM COBAAR","TK-3001 CDCBM PATCOM","TK-3001 CDCBM PATCOM","TK-3001 CDCBM PATCOM","CC-3054 CDCBM BLUSDQ","CC-3054 CDCBM BLUSDQ","CC-3054 CDCBM BLUSDQ","CC-3054 CDCBM COBAAR","CC-3054 CDCBM COBAAR","CC-3054 CDCBM COBAAR","CC-3054 CDCBM BLACDT","CC-3054 CDCBM BLACDT","CC-3054 CDCBM BLACDT","CC-3054 CDCBM PATCOM","CC-3054 CDCBM PATCOM","CC-3054 CDCBM PATCOM"],"isClosed":false,"lineItemsInfo":[{"sku":"TK2035 CDCBM COBAAR 2ZZSM","quantity":1,"id":"recYUfblFTF68IhSW"},{"sku":"TK2035 CDCBM BLACDT 2ZZSM","quantity":1,"id":"recmpzJdERsVZc6fZ"},{"sku":"TK2035 CDCBM COBAAR 2ZZSM","quantity":1,"id":"rec6IYbLVZMncd6Ze"},{"sku":"TK2035 CDCBM COBAAR 2ZZSM","quantity":1,"id":"rechaaHpHwP61JIPQ"},{"sku":"TK2035 CDCBM BLACDT 2ZZSM","quantity":1,"id":"recEa80qFQZcJmVqV"},{"sku":"TK2035 CDCBM BLACDT 2ZZSM","quantity":1,"id":null},{"sku":"TK2035 CDCBM PATCOM 2ZZSM","quantity":1,"id":"recp2HCivp1anT8D6"},{"sku":"TK2035 CDCBM PATCOM 2ZZSM","quantity":1,"id":null},{"sku":"TK2035 CDCBM PATCOM 2ZZSM","quantity":1,"id
M","quantity":1,"id":null},{"sku":"TK3010 CDCBM BLACDT 2ZZSM","quantity":1,"id":"recHuzfClVdMrFTzr"},{"sku":"TK3010 CDCBM BLACDT 2ZZSM","quantity":1,"id":null},{"sku":"TK3010 CDCBM BLACDT 2ZZSM","quantity":1,"id":null},{"sku":"TK3001 CDCBM COBAAR 2ZZSM","quantity":1,"id":"recrQDUCMFqNFagvf"},{"sku":"TK3001 CDCBM COBAAR 2ZZSM","quantity":1,"id":null},{"sku":"TK3001 CDCBM COBAAR 2ZZSM","quantity":1,"id":null},{"sku":"TK3001 CDCBM PATCOM 2ZZSM","quantity":1,"id":"rechPdal5p9IfPwRI"},{"sku":"TK3001 CDCBM PATCOM 2ZZSM","quantity":1,"id":null},{"sku":"TK3001 CDCBM PATCOM 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM BLUSDQ 2ZZSM","quantity":1,"id":"recG5JT8blkcEgPmO"},{"sku":"CC3054 CDCBM BLUSDQ 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM BLUSDQ 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM COBAAR 2ZZSM","quantity":1,"id":"recbU19eRm6ouaxox"},{"sku":"CC3054 CDCBM COBAAR 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM COBAAR 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM BLACDT 2ZZSM","quantity":1,"id":"recMY9T8UrZAihA3L"},{"sku":"CC3054 CDCBM BLACDT 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM BLACDT 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM PATCOM 2ZZSM","quantity":1,"id":"recom02pzidYqV0NQ"},{"sku":"CC3054 CDCBM PATCOM 2ZZSM","quantity":1,"id":null},{"sku":"CC3054 CDCBM PATCOM 2ZZSM","quantity":1,"id":null}],"numberLineItems":63,"lineItemsCreated":63,"firstTouchSent":false,"secondTouchSent":false,"thirthTouchSent":false,"hasItemsFlaggedForReview":true,"deadlineStatus":"On Time","releaseStatus":"HOLD","isFlaggedForReview":false,"orderStatusV3":"Open","daysOpenInMake":63,"activeIssuesIds":[],"daysSinceOrder":10,"holdEmail":false,"isOrderClosed":false}
"""''

event = json.loads(json_message)
# event = {
#     "id":"",#nullable 
#     "isArchived":False,#nullable
#     "key":"",# BG-2126371 Basicaly BrandC0de-Key
#     "code":"",# Not sure what this was
#     "number": "",#2126371 order number that goes on the key also
#     "friendlyName": "", #ONE Size ONE Label 
#     "requestName": "", #ONE Size ONE Label Seams to be the same as friendlyName
#     "email": "", #ssalomonsky@resonance.nyc
#     "brandId": [""], #recWYyQdeaWUdPaKQ for now I asume is one ID the record Id of the brand
#     "brandCode": [""], #BG
#     "brandName": [""], #BruceGlen
#     "orderChannel": "resmagic.io", #resmagic.io Always 
#     "salesChannel": "",#
#     "fulfillmentId": [""], #?????
#     "lineItemIds": [""], # I asume we don't have this  maybe we can have IDS 
#     "containsExternalItem": False, #nullable, 
#     "shippingAddress1": "",
#     "shippingAddress2": "",
#     "shippingCity": "",
#     "shippingZip": "",
#     "shippingCountry": "",
#     "shippingProvince": "",
#     "shippingName": "",
#     "shippingPhone": "",
#     "orderStatus": "", #At start 'IN PROGRESS' is the first statu  #releaseStatus: 'HOLD' after we post for payment 
#     "isClosedv2": "", #Maybe we don't need this is not needed 
#     "requestType": "",#Finished Goods, Fabric, Strike Off, Sample, Checkout Request.
#     "createdAt": "", #Date string
#     "keyid": "", #2126371 same as number
#     "styleCodes": [""], #rec4Kvu4nDXmiBHfj,rec4Kvu4nDXmiBHfj,rec4Kvu4nDXmiBHfj,rec4Kvu4nDXmiBHfj,rec4Kvu4nDXmiBHfj,rec4Kvu4nDXmiBHfj,rec4Kvu4nDXmiBHfj
#     "isClosed": False, #nullable
#     "lineItemsInfo": [{}], #this is the Json object array for lineItems before lineItems instance is created
#     "numberLineItems": 0, #Amount of line items 
#     "lineItemsCreated": 0, #Not sure if this is the same thing
#     "firstTouchSent": False, #This Is email notifications
#     "secondTouchSent": False,
#     "thirthTouchSent": False,
#     "hasItemsFlaggedForReview": False,
#     "deadlineStatus": "", #Late, On Time, Time at Risk
#     "releaseStatus": "", #HOLD, RELEASE, hold
#     "isFlaggedForReview": False,
#     "orderStatusV3": "",
#     "daysOpenInMake": 0,
#     "activeIssuesIds": [""],
#     "daysSinceOrder": 0,
#     "holdEmail": False,
#     "isOrderClosed": False
# }



#Example 


 
# {
#    "id": "recijvDbpZTMZorO9",
#    "isArchived": false,
#    "key": "BS-2123118",
#    "code": "2123118",
#    "number": "2123118",
#    "friendlyName": "test",
#    "requestName": "test",
#    "email": "dgomez@resonance.nyc",
#    "brandId": [
#       "recagRmt5QFz7H240"
#    ],
#    "brandCode": [
#       "BS"
#    ],
#    "brandName": [
#       "Brand Success"
#    ],
#    "orderChannel": "resmagic.io",
#    "salesChannel": "Development",
#    "fulfillmentId": [
#       "rec56uUFhzKV4AxSl"
#    ],
#    "lineItemIds": [
#       "reclMyYfc4FkEjHe9"
#    ],
#    "containsExternalItem": false,
#    "shippingAddress1": "ATTN: Sarah Salomonsky",
#    "shippingAddress2": "59 Chelsea Piers",
#    "shippingCity": "New York City",
#    "shippingZip": "10011",
#    "shippingCountry": "United States",
#    "shippingProvince": "NY",
#    "shippingName": "Resonance Companies",
#    "shippingPhone": "+1 (804) 363-1081",
#    "orderStatus": "⚙️Open Fulfillments",
#    "isClosedv2": "1",
#    "requestType": "Finished Goods",
#    "createdAt": "2022-12-13T17:58:24.000Z",
#    "keyid": "2123118",
#    "styleCodes": [
#       "CC-9011 CFT97 PINKUY"
#    ],
#    "isClosed": false,
#    "lineItemsInfo": [
#       {
#          "sku": "CC9011 CFT97 PINKUY 0ZZOS",
#          "quantity": 1,
#          "id": "reclMyYfc4FkEjHe9"
#       }
#    ],
#    "numberLineItems": 1,
#    "lineItemsCreated": 1,
#    "firstTouchSent": false,
#    "secondTouchSent": false,
#    "thirthTouchSent": false,
#    "hasItemsFlaggedForReview": false,
#    "deadlineStatus": "On Time",
#    "releaseStatus": "HOLD",
#    "isFlaggedForReview": false,
#    "orderStatusV3": "Open",
#    "daysOpenInMake": 1,
#    "activeIssuesIds": [],
#    "daysSinceOrder": 0,
#    "holdEmail": false,
#    "isOrderClosed": false
# }




#salesChannel Options: 
#Wholesale
#PHOTO
#GIFTING
#Checkout Request
#Development

#LineItems Info

# [
#     {
#         "id": "recLj9YT4invdhGYc",  #Style Id 
#         "sku": "CC9007 CTNOX OLXSEN 0ZZOS", 
#         "quantity": 1,
#         "orderId": null,
#         "orderNumber": null,
#         "channelOrderLineItemId": null,
#         "productName": null,
#         "productVariantTitle": null,
#         "lineItemPrice": null,
#         "shopifyFulfillmentStatus": null,
#         "shopifyFulfillableQuantity": null,
#         "customizations": null
#     },
#     {
#         "id": "recLj9YT4invdhGYc",
#         "sku": "CC9007 CTNOX OLXSEN 0ZZOS",
#         "quantity": 1,
#         "orderId": null,
#         "orderNumber": null,
#         "channelOrderLineItemId": null,
#         "productName": null,
#         "productVariantTitle": null,
#         "lineItemPrice": null,
#         "shopifyFulfillmentStatus": null,
#         "shopifyFulfillableQuantity": null,
#         "customizations": null
#     },
   
# ]


# Deadine Status  Rule 
# IF({ONEs Open in Make}>0,IF({Days Since Order (Business Days)}>10,"Late",IF({Days Since Order (Business Days)}<=7,"On Time","Time at Risk")))

#Order Status V3 
#IF({Order Fulfillment Status} = 'CANCELED', "Canceled" ,IF({Order Fulfillment Status} = 'FULFILLED', IF({Order Channel} = 'Shopify', IF({is_closed_shopify}, "Fulfilled", "Shipping"), "Fulfilled"), "Open"))

# await createMakeOneOrderMutation({
#     variables: {
#         input: {
#             requestName: requestName,
#             brandId: user.activeBrandWorkspace.code,
#             email: user.email,
#             salesChannel: salesChannel,
#             orderChannel: 'resmagic.io',
#             shippingName: shippingName,
#             shippingAddress1: shippingAddress1,
#             shippingAddress2: shippingAddress2,
#             shippingCity: shippingCity,
#             shippingCountry: shippingCountry,
#             shippingProvince: shippingProvince,
#             shippingZip: shippingZip,
#             shippingPhone: shippingPhone,
#             lineItemsInfo: lineItems
#         }
#     }
# })

#Create a new test create one Order From the mutation

# %%
import os
from res.flows.sell.orders.process import create_one_handler
print(event)
print("EVENT ^^^^^")

os.environ['RES_ENV'] = 'development'

##Call the side effects for this data this is actually going through Kafka 
result = create_one_handler(event)
print(result)
# Out:
# 2023-02-22 14:51.40 [info     ] Log level set to 10
# 2023-02-22 14:51.40 [warning  ] Sentry integration not enabled, skipping sentry init.
# 2023-02-22 14:51.41 [debug    ] Set up metrics provider: <res.utils.logging.ResLogger.DummyMetricsProvider object at 0x12abcd700>
# 2023-02-22 14:51.43 [debug    ] Module 'res' finished initializing!
# ...

# %%
#This is how we get a style data by ID we are going to need it for product Assingmint if needed. 
# Or if its not assinged. 

from res.flows.sell.orders.queries import get_style_by_id

print(get_style_by_id("recqoU2T5GwwU0MVR"))
